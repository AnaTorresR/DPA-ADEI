# %%
import pandas as pd

# %% [markdown]
# Pruebas de sodapy api para dataset food inspections

# %%
import sys
sys.path.append('../')

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from src.pipeline.ingesta_almacenamiento import get_client, ingesta_inicial

# %%
dataset_domain = "data.cityofchicago.org"
dataset_id = "4ijn-s7e5"
token = "TXHg23hGeRkgoxUk45gtc5X1m"

# %%
food_client = get_client(dataset_domain, token)

# %%
food_client

# %%
df_food = ingesta_inicial(food_client,dataset_id)

# %%
df_food
# Out:
#                    0                             1   \
# 0       inspection_id                      dba_name
# 1             2484759                   Jimmy Johns
# 2             2484775                  CAFE TOLA #4
# 3             2484768    MARZ COMMINITY BREWING CO.
# 4             2484780              RED STAR LIQUORS
# ...               ...                           ...
# 216481         104236                    TEMPO CAFE
# 216482          52234                      Cafe 608
# 216483          67757  DUNKIN DONUTS/BASKIN-ROBBINS
# 216484          70269                   mr.daniel's
# 216485          67732                     WOLCOTT'S
#
#                                   2         3              4   \
# 0                           aka_name  license_  facility_type
# 1                        Jimmy Johns   1898470     Restaurant
# 2                          CAFE TOLA   2627325     Restaurant
# 3         MARZ COMMUNITY BREWING CO.   2770949         Liquor
# ...
