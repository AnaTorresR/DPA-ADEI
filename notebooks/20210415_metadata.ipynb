# %%
import pickle

from src.utils.utils_notebook.cleaning import *
from src.utils.utils_notebook.feature_engineering import *

# %%
datos = pickle.load(open("../temp/data-product-architecture-equipo-6/ingestion/consecutive/consecutive-inspections-2021-03-18.pkl","rb"))

# %%
datos = cleaning(datos)

# %%
datos
# Out:
#     inspection_id                         dba_name  \
# 0         2492688            indio cocina mexicana
# 1         2492644         volcano sushi restaurant
# 2         2492670                  el michoacanito
# 3         2492664                mary crane league
# 4         2492672                     millard food
# ..            ...                              ...
# 136       2492849                  burrito station
# 137       2492939                 jack and gingers
# 138       2492937               hanson park branch
# 139       2492907  whipped & beaten culinary works
# 140       2492904                winthrop children
#
#                             aka_name license_                 facility_type  \
# 0              indio cocina mexicana  1441906                    restaurant
# 1           volcano sushi restaurant  2699569                    restaurant
# 2                    el michoacanito  2385718                    restaurant
# 3                  mary crane league  2245628  children's services facility
# 4                       millard food  2442819                 grocery store
# ..                               ...      ...                           ...
# 136                  burrito station  1675565                    restaurant
# 137                 jack and gingers  1767508                    restaurant
# 138               hanson park branch    24462                        school
# 139  whipped & beaten culinary works  2776158                cooking school
# 140                 wnthrop children  2215541         daycare (2 - 6 years)
#
#                 risk                  address     city state    zip  \
# 0      risk 1 (high)          3930 w 63rd st   chicago    il  60629
# 1      risk 1 (high)   2521 n california ave   chicago    il  60647
# 2      risk 1 (high)  4311-4315 n kedzie ave   chicago    il  60618
# 3      risk 1 (high)       2905 n leavitt st   chicago    il  60618
# 4    risk 2 (medium)          3638 w 16th st   chicago    il  60623
# ..               ...                      ...      ...   ...    ...
# 136    risk 1 (high)         2750 w 111th st   chicago    il  60655
# 137    risk 1 (high)     2048 w armitage ave   chicago    il  60647
# 138    risk 1 (high)         2318 n lorel st   chicago    il  60639
# 139     risk 3 (low)    3611-3617 n broadway   chicago    il  60613
# 140    risk 1 (high)     4848 n winthrop ave   chicago    il  60640
#
#     inspection_date          inspection_type             results  \
# 0        2021-03-10                  canvass                pass
# 1        2021-03-10    canvass re-inspection                pass
# 2        2021-03-10           non-inspection            no entry
# 3        2021-03-10    license re-inspection                pass
# 4        2021-03-10  complaint re-inspection                pass
# ..              ...                      ...                 ...
# 136      2021-03-15                  canvass  pass w/ conditions
# 137      2021-03-16           non-inspection            no entry
# 138      2021-03-16                  canvass                pass
# 139      2021-03-16                  license                pass
# 140      2021-03-16                  canvass     out of business
#
#                                             violations            latitude  \
# 0    37. food properly labeled; original container ...   41.77878423669901
# 1                                                  NaN   41.92723033363832
# 2                                                  NaN   41.95974034065365
# 3                                                  NaN  41.934280416256804
# 4                                                  NaN   41.85906468430445
# ..                                                 ...                 ...
# 136  5. procedures for responding to vomiting and d...    41.6918029183953
# 137                                                NaN  41.917829917196265
# 138  55. physical facilities installed, maintained ...  41.922831144138776
# 139                                                NaN   41.94773174730859
# 140                                                NaN   41.97048400251602
#
#               longitude                                           location
# 0    -87.72157517203811  {'latitude': '-87.72157517203811', 'longitude'...
# 1    -87.69733417567808  {'latitude': '-87.69733417567808', 'longitude'...
# 2    -87.70805402090488  {'latitude': '-87.70805402090488', 'longitude'...
# 3    -87.68290782429251  {'latitude': '-87.68290782429251', 'longitude'...
# 4    -87.71667499753184  {'latitude': '-87.71667499753184', 'longitude'...
# ..                  ...                                                ...
# 136  -87.69038573111922  {'latitude': '-87.69038573111922', 'longitude'...
# 137  -87.67953075090323  {'latitude': '-87.67953075090323', 'longitude'...
# 138  -87.75994374773492  {'latitude': '-87.75994374773492', 'longitude'...
# 139  -87.64734303203468  {'latitude': '-87.64734303203468', 'longitude'...
# 140  -87.65780618896973  {'latitude': '-87.65780618896973', 'longitude'...
#
# [141 rows x 17 columns]

# %%
datos.fix_typos()

# %%
datos = feature_engineering(datos)

# %%
def changeType_date(df):
        df['inspection_date'] = pd.to_datetime(df['inspection_date'])
        return df

# %%
changeType_date(datos)

# %% [markdown]
# # Cleaning/Preprocessing

# %% [markdown]
# # Metadata
# ## Ingestión

# %%
data

# %%
def get_s3_credentials(credentials_file):
    credentials = read_yaml_file(credentials_file)
    s3_creds = credentials['db']
    return s3_creds

# %%
data

# %%
# !pip install psycopg2

# %%
import psycopg2
import yaml

def get_db_conn(creds_file):
    """ Get an authenticated psycopg db connection, given a credentials file"""
    creds = read_yaml_file(creds_file)
    
    creds = creds['db']

    connection = psycopg2.connect(
        user=creds['user'],
        password=creds['pass'],
        host=creds['host'],
        port=creds['port'],
        database=creds['db']
    )
    
def read_yaml_file(yaml_file):
    """ load yaml cofigurations """
    config = None
    try:
        with open(yaml_file, 'r') as f:
            config = yaml.safe_load(f)
    except:
        raise FileNotFoundError('Couldnt load the file')

    return config

# %%
with open('../conf/local/credentials.yaml', 'r') as f:
        config = yaml.safe_load(f)

# %%
a = read_yaml_file('../conf/local/credentials.yaml')

# %%
def get_db_conn(creds_file):
    credentials = read_yaml_file(creds_file)
    db_creds = credentials['db']
    return db_creds

# %%
credentials = get_db_conn('../conf/local/credentials.yaml')

credentials

# %%
credentials['port']

# %%
user=db_creds['user'],
password=db_creds['pass'],
host=db_creds['host'],
port=db_creds['port'],
database=db_creds['db']

# %%
def get_db_conn(credentials_file):
    credentials = read_yaml_file(credentials_file)
    db_creds = credentials['db']
    return db_creds

# %%
db_creds = get_db_conn('../conf/local/credentials.yaml')

# %%
user=db_creds['user'],
password=db_creds['pass'],
host=db_creds['host'],
port=db_creds['port'],
database=db_creds['db']

# %%
user
